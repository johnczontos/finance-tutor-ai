# %%
from youtube_transcript_api import YouTubeTranscriptApi

video_id = "fPlbLcnFMBY"  # Example ID
transcript = YouTubeTranscriptApi.get_transcript(video_id)

transcript
# Out:
# [{'text': 'so chapter one has to do with the',
#   'start': 4.88,
#   'duration': 4.559},
#  {'text': 'introduction to', 'start': 6.6, 'duration': 2.839},
#  {'text': 'finance so what is finance so rather',
#   'start': 10.08,
#   'duration': 6.0},
#  {'text': 'than thinking of Finance is one thing it',
#   'start': 13.48,
#   'duration': 4.2},
#  {'text': 'might be better to think of Finance as',
#   'start': 16.08,
#   'duration': 4.08},
#  {'text': 'an architecture of components that when',
#   'start': 17.68,
#   'duration': 4.4},
#  {'text': 'combined facilitate companies and',
#   'start': 20.16,
#   'duration': 3.879},
#  {'text': 'individuals to initiate manage and',
#   'start': 22.08,
#   'duration': 4.359},
#  {'text': 'sustain their businesses there are many',
#   'start': 24.039,
#   'duration': 4.08},
#  {'text': 'members of the finance family including',
#   'start': 26.439,
#   'duration': 3.521},
#  {'text': 'business finance Investments and Fin',
# ...
